# %% [markdown]
# This notebook contains exploratory data analysis on FAERS using the api.
#
# Author - Akshay Chougule<br>
# Created on - 5th November 2020<br>
# Last Updated - 6th November 2020<br>
# <br>
# [Reference](https://open.fda.gov/apis/drug/event/how-to-use-the-endpoint/)

# %%
import pandas as pd
import numpy as np
import requests
import datetime
import json
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('max_colwidth', 800)

# %% [markdown]
# ## bevacizumab

# %% [markdown]
# ### case-level query

# %%
# to get individual case records
query_url = 'https://api.fda.gov/drug/event.json?search=bevacizumab&limit=1000&skip=0'
# We can keep increasing skip by the limit number in the subsquent calls to get the next batch of the data
r = requests.get(query_url)
j = json.loads(r.content)

# %%
len(j['results'])
# Out:
# 1000

# %%
j.keys()
# Out:
# dict_keys(['meta', 'results'])

# %%
j['meta']
# Out:
# {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#  'terms': 'https://open.fda.gov/terms/',
#  'license': 'https://open.fda.gov/license/',
#  'last_updated': '2020-11-01',
#  'results': {'skip': 0, 'limit': 1000, 'total': 77627}}

# %%
len(j['results'])
# Out:
# 1000

# %%
j['results'][0].keys()
# Out:
# dict_keys(['reporttype', 'safetyreportversion', 'receivedateformat', 'primarysource', 'transmissiondateformat', 'fulfillexpeditecriteria', 'safetyreportid', 'patient', 'serious', 'reportduplicate', 'receiptdate', 'receiptdateformat', 'receiver', 'seriousnessdeath', 'companynumb', 'occurcountry', 'duplicate', 'sender', 'receivedate', 'transmissiondate', 'primarysourcecountry'])

# %%
j['results'][0]['patient'].keys()
# Out:
# dict_keys(['reaction', 'patientsex', 'drug'])

# %%
len(j['results'][0]['patient'])
# Out:
# 3

# %%
j['results'][0]['patient']
# Out:
# {'reaction': [{'reactionmeddraversionpt': '17.0',
#    'reactionmeddrapt': 'Death',
#    'reactionoutcome': '5'}],
#  'patientsex': '1',
#  'drug': [{'drugindication': 'COLORECTAL CANCER METASTATIC',
#    'drugadministrationroute': '042',
#    'drugcharacterization': '1',
#    'openfda': {'product_ndc': ['50242-060', '50242-061'],
#     'spl_id': ['bcde0461-1e76-4e4c-a643-1543436d2cda'],
#     'substance_name': ['BEVACIZUMAB'],
#     'product_type': ['HUMAN PRESCRIPTION DRUG'],
#     'route': ['INTRAVENOUS'],
#     'package_ndc': ['50242-060-01',
#      '50242-060-10',
#      '50242-061-01',
#      '50242-061-10'],
#     'generic_name': ['BEVACIZUMAB'],
#     'spl_set_id': ['939b5d1f-9fb2-4499-80ef-0607aa6b114e'],
#     'brand_name': ['AVASTIN'],
#     'application_number': ['BLA125085'],
#     'manufacturer_name': ['Genentech, Inc.'],
#     'unii': ['2S9ZZM9Q9V']},
#    'drugauthorizationnumb': '125085',
#    'medicinalproduct': 'AVASTIN'}]}

# %% [markdown]
# ### aggregated query

# %%
# to get aggregated data
query_url = 'https://api.fda.gov/drug/event.json?search=patient.drug.openfda.brand_name:%22avastin%22+AND+serious:1+AND+patient.patientsex:1+AND+receivedate:[2013-01-01+TO+2013-12-31]&count=patient.reaction.reactionmeddrapt.exact&limit=1000&skip=0'
# We can keep increasing skip by the limit number in the subsquent calls to get the next batch of the data
r = requests.get(query_url)
j = json.loads(r.content)

# %%
j
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2020-11-01'},
#  'results': [{'term': 'DEATH', 'count': 420},
#   {'term': 'DISEASE PROGRESSION', 'count': 256},
#   {'term': 'DIARRHOEA', 'count': 106},
#   {'term': 'NAUSEA', 'count': 98},
#   {'term': 'VOMITING', 'count': 92},
#   {'term': 'FATIGUE', 'count': 72},
#   {'term': 'OFF LABEL USE', 'count': 71},
#   {'term': 'PYREXIA', 'count': 66},
#   {'term': 'GENERAL PHYSICAL HEALTH DETERIORATION', 'count': 63},
#   {'term': 'ABDOMINAL PAIN', 'count': 60},
#   {'term': 'ASTHENIA', 'count': 58},
#   {'term': 'PNEUMONIA', 'count': 53},
#   {'term': 'DYSPNOEA', 'count': 51},
#   {'term': 'CONSTIPATION', 'count': 49},
#   {'term': 'HYPERTENSION', 'count': 48},
#   {'term': 'MALIGNANT NEOPLASM PROGRESSION', 'count': 46},
#   {'term': 'WEIGHT DECREASED', 'count': 43},
#   {'term': 'FEBRILE NEUTROPENIA', 'count': 42},
#   {'term': 'CONFUSIONAL STATE', 'count': 41},
#   {'term': 'PLATELET COUNT DECREASED', 'count': 39},
#   {'term': 'DECREASED APPETITE', 'count': 38},
#   {'term': 'DEHYDRATION', 'count': 38},
#   {'term': 'PULMONARY EMBOLISM', 'count': 36},
#   {'term': 'EPISTAXIS', 'count': 35},
#   {'term': 'INTERSTITIAL LUNG DISEASE', 'count': 35},
#   {'term': 'NEUROPATHY PERIPHERAL', 'count': 35},
#   {'term': 'NEUTROPENIA', 'count': 35},
#   {'term': 'HEADACHE', 'count': 33},
#   {'term': 'RASH', 'count': 33},
#   {'term': 'PAIN', 'count': 32},
#   {'term': 'SEPSIS', 'count': 32},
#   {'term': 'CONVULSION', 'count': 31},
#   {'term': 'HYPOTENSION', 'count': 31},
#   {'term': 'VISION BLURRED', 'count': 30},
#   {'term': 'ANAEMIA', 'count': 29},
#   {'term': 'DRUG INEFFECTIVE', 'count': 29},
#   {'term': 'FALL', 'count': 29},
#   {'term': 'RENAL FAILURE ACUTE', 'count': 29},
#   {'term': 'VISUAL ACUITY REDUCED', 'count': 29},
#   {'term': 'BACK PAIN', 'count': 28},
#   {'term': 'BLOOD PRESSURE INCREASED', 'count': 27},
#   {'term': 'HAEMOGLOBIN DECREASED', 'count': 26},
#   {'term': 'THROMBOCYTOPENIA', 'count': 26},
#   {'term': 'RENAL FAILURE', 'count': 25},
#   {'term': 'STOMATITIS', 'count': 25},
#   {'term': 'COUGH', 'count': 24},
#   {'term': 'DIZZINESS', 'count': 24},
#   {'term': 'INFECTION', 'count': 24},
#   {'term': 'ATRIAL FIBRILLATION', 'count': 23},
#   {'term': 'GAIT DISTURBANCE', 'count': 23},
#   {'term': 'MALAISE', 'count': 22},
#   {'term': 'METASTASES TO LIVER', 'count': 22},
#   {'term': 'METASTASES TO LUNG', 'count': 22},
#   {'term': 'MUCOSAL INFLAMMATION', 'count': 22},
#   {'term': 'WHITE BLOOD CELL COUNT DECREASED', 'count': 22},
#   {'term': 'CEREBROVASCULAR ACCIDENT', 'count': 21},
#   {'term': 'DYSPHAGIA', 'count': 21},
#   {'term': 'NEUTROPHIL COUNT DECREASED', 'count': 21},
#   {'term': 'PALMAR-PLANTAR ERYTHRODYSAESTHESIA SYNDROME', 'count': 21},
#   {'term': 'PNEUMOTHORAX', 'count': 21},
#   {'term': 'DEEP VEIN THROMBOSIS', 'count': 20},
#   {'term': 'HYPOAESTHESIA', 'count': 20},
#   {'term': 'PLEURAL EFFUSION', 'count': 20},
#   {'term': 'VISUAL IMPAIRMENT', 'count': 20},
#   {'term': 'BLINDNESS', 'count': 19},
#   {'term': 'HEPATIC FAILURE', 'count': 19},
#   {'term': 'RETINAL HAEMORRHAGE', 'count': 19},
#   {'term': 'ARTHRALGIA', 'count': 18},
#   {'term': 'GASTROINTESTINAL HAEMORRHAGE', 'count': 18},
#   {'term': 'HAEMOPTYSIS', 'count': 18},
#   {'term': 'VARICES OESOPHAGEAL', 'count': 18},
#   {'term': 'DRY SKIN', 'count': 17},
#   {'term': 'OEDEMA PERIPHERAL', 'count': 17},
#   {'term': 'ASCITES', 'count': 16},
#   {'term': 'CHEST PAIN', 'count': 16},
#   {'term': 'HAEMORRHAGE', 'count': 16},
#   {'term': 'INTESTINAL OBSTRUCTION', 'count': 16},
#   {'term': 'MYOCARDIAL INFARCTION', 'count': 16},
#   {'term': 'PROTEINURIA', 'count': 16},
#   {'term': 'RESPIRATORY FAILURE', 'count': 16},
#   {'term': 'SOMNOLENCE', 'count': 16},
#   {'term': 'ABDOMINAL DISTENSION', 'count': 15},
#   {'term': 'GASTROINTESTINAL PERFORATION', 'count': 15},
#   {'term': 'IMPAIRED HEALING', 'count': 15},
#   {'term': 'METASTASES TO CENTRAL NERVOUS SYSTEM', 'count': 15},
#   {'term': 'SPLENOMEGALY', 'count': 15},
#   {'term': 'INTESTINAL PERFORATION', 'count': 14},
#   {'term': 'LARGE INTESTINE PERFORATION', 'count': 14},
#   {'term': 'MENTAL STATUS CHANGES', 'count': 14},
#   {'term': 'MUSCULAR WEAKNESS', 'count': 14},
#   {'term': 'NEOPLASM', 'count': 14},
#   {'term': 'PARAESTHESIA', 'count': 14},
#   {'term': 'THROMBOSIS', 'count': 14},
#   {'term': 'VITREOUS FLOATERS', 'count': 14},
#   {'term': 'BONE MARROW FAILURE', 'count': 13},
#   {'term': 'CATARACT', 'count': 13},
#   {'term': 'HEART RATE INCREASED', 'count': 13},
#   {'term': 'HYPOKALAEMIA', 'count': 13},
#   {'term': 'OEDEMA', 'count': 13},
#   {'term': 'WEIGHT INCREASED', 'count': 13},
#   {'term': 'ABDOMINAL PAIN UPPER', 'count': 12},
#   {'term': 'CARDIAC FAILURE', 'count': 12},
#   {'term': 'CYSTOID MACULAR OEDEMA', 'count': 12},
#   {'term': 'LOSS OF CONSCIOUSNESS', 'count': 12},
#   {'term': 'MULTI-ORGAN FAILURE', 'count': 12},
#   {'term': 'PROTEIN URINE PRESENT', 'count': 12},
#   {'term': 'PRURITUS', 'count': 12},
#   {'term': 'RENAL IMPAIRMENT', 'count': 12},
#   {'term': 'RESPIRATORY DISTRESS', 'count': 12},
#   {'term': 'BLOOD CREATININE INCREASED', 'count': 11},
#   {'term': 'CHILLS', 'count': 11},
#   {'term': 'DISSEMINATED INTRAVASCULAR COAGULATION', 'count': 11},
#   {'term': 'DYSPHONIA', 'count': 11},
#   {'term': 'HYPERSENSITIVITY', 'count': 11},
#   {'term': 'HYPONATRAEMIA', 'count': 11},
#   {'term': 'JAUNDICE', 'count': 11},
#   {'term': 'LACRIMATION INCREASED', 'count': 11},
#   {'term': 'LUNG DISORDER', 'count': 11},
#   {'term': 'LUNG INFECTION', 'count': 11},
#   {'term': 'MUSCULOSKELETAL PAIN', 'count': 11},
#   {'term': 'NASOPHARYNGITIS', 'count': 11},
#   {'term': 'PERITONITIS', 'count': 11},
#   {'term': 'SYNCOPE', 'count': 11},
#   {'term': 'TUMOUR HAEMORRHAGE', 'count': 11},
#   {'term': 'URINARY TRACT INFECTION', 'count': 11},
#   {'term': 'BALANCE DISORDER', 'count': 10},
#   {'term': 'CARDIAC ARREST', 'count': 10},
#   {'term': 'COLON CANCER METASTATIC', 'count': 10},
#   {'term': 'DYSGEUSIA', 'count': 10},
#   {'term': 'GLIOBLASTOMA', 'count': 10},
#   {'term': 'HEMIPARESIS', 'count': 10},
#   {'term': 'INTERNATIONAL NORMALISED RATIO INCREASED', 'count': 10},
#   {'term': 'LETHARGY', 'count': 10},
#   {'term': 'NEOPLASM PROGRESSION', 'count': 10},
#   {'term': 'OESOPHAGEAL VARICES HAEMORRHAGE', 'count': 10},
#   {'term': 'ACUTE KIDNEY INJURY', 'count': 9},
#   {'term': 'AGITATION', 'count': 9},
#   {'term': 'CARDIO-RESPIRATORY ARREST', 'count': 9},
#   {'term': 'CEREBRAL INFARCTION', 'count': 9},
#   {'term': 'DRUG INTERACTION', 'count': 9},
#   {'term': 'DYSPNOEA EXERTIONAL', 'count': 9},
#   {'term': 'EMBOLISM', 'count': 9},
#   {'term': 'ERYTHEMA', 'count': 9},
#   {'term': 'EYE PAIN', 'count': 9},
#   {'term': 'GASTROINTESTINAL DISORDER', 'count': 9},
#   {'term': 'HYPERAMMONAEMIC ENCEPHALOPATHY', 'count': 9},
#   {'term': 'MACULAR OEDEMA', 'count': 9},
#   {'term': 'METASTASIS', 'count': 9},
#   {'term': 'NEOPLASM MALIGNANT', 'count': 9},
#   {'term': 'PAIN IN EXTREMITY', 'count': 9},
#   {'term': 'PNEUMATOSIS INTESTINALIS', 'count': 9},
#   {'term': 'PORTAL HYPERTENSION', 'count': 9},
#   {'term': 'RED BLOOD CELL COUNT DECREASED', 'count': 9},
#   {'term': 'TACHYCARDIA', 'count': 9},
#   {'term': 'WOUND COMPLICATION', 'count': 9},
#   {'term': 'ALANINE AMINOTRANSFERASE INCREASED', 'count': 8},
#   {'term': 'ANXIETY', 'count': 8},
#   {'term': 'BRAIN OEDEMA', 'count': 8},
#   {'term': 'CEREBRAL HAEMORRHAGE', 'count': 8},
#   {'term': 'ENDOPHTHALMITIS', 'count': 8},
#   {'term': 'EYE HAEMORRHAGE', 'count': 8},
#   {'term': 'GASTROOESOPHAGEAL REFLUX DISEASE', 'count': 8},
#   {'term': 'HAEMATOCHEZIA', 'count': 8},
#   {'term': 'HAEMATOTOXICITY', 'count': 8},
#   {'term': 'HAEMATURIA', 'count': 8},
#   {'term': 'ILEUS', 'count': 8},
#   {'term': 'INTRAOCULAR PRESSURE INCREASED', 'count': 8},
#   {'term': 'LEUKOPENIA', 'count': 8},
#   {'term': 'MYCOTIC ENDOPHTHALMITIS', 'count': 8},
#   {'term': 'OSTEONECROSIS OF JAW', 'count': 8},
#   {'term': 'TRANSIENT ISCHAEMIC ATTACK', 'count': 8},
#   {'term': 'VITREOUS HAEMORRHAGE', 'count': 8},
#   {'term': 'ABDOMINAL DISCOMFORT', 'count': 7},
#   {'term': 'ABSCESS', 'count': 7},
#   {'term': 'ALTERED STATE OF CONSCIOUSNESS', 'count': 7},
#   {'term': 'APHASIA', 'count': 7},
#   {'term': 'ASPARTATE AMINOTRANSFERASE INCREASED', 'count': 7},
#   {'term': 'COLITIS', 'count': 7},
#   {'term': 'CONTUSION', 'count': 7},
#   {'term': 'DERMATITIS ACNEIFORM', 'count': 7},
#   {'term': 'DUODENAL ULCER', 'count': 7},
#   {'term': 'DYSARTHRIA', 'count': 7},
#   {'term': 'ENCEPHALOPATHY', 'count': 7},
#   {'term': 'GASTROINTESTINAL CARCINOMA', 'count': 7},
#   {'term': 'HAEMATOCRIT DECREASED', 'count': 7},
#   {'term': 'INCONTINENCE', 'count': 7},
#   {'term': 'INSOMNIA', 'count': 7},
#   {'term': 'LARGE INTESTINAL OBSTRUCTION', 'count': 7},
#   {'term': 'LYMPHOCYTE COUNT DECREASED', 'count': 7},
#   {'term': 'METASTATIC NEOPLASM', 'count': 7},
#   {'term': 'MUSCLE SPASMS', 'count': 7},
#   {'term': 'NEUROTOXICITY', 'count': 7},
#   {'term': 'RASH ERYTHEMATOUS', 'count': 7},
#   {'term': 'RECTAL HAEMORRHAGE', 'count': 7},
#   {'term': 'SALIVARY HYPERSECRETION', 'count': 7},
#   {'term': 'SEIZURE', 'count': 7},
#   {'term': 'SMALL INTESTINAL OBSTRUCTION', 'count': 7},
#   {'term': 'SPEECH DISORDER', 'count': 7},
#   {'term': 'SUBILEUS', 'count': 7},
#   {'term': 'TUMOUR PERFORATION', 'count': 7},
#   {'term': 'UPPER GASTROINTESTINAL HAEMORRHAGE', 'count': 7},
#   {'term': 'WHITE BLOOD CELL COUNT INCREASED', 'count': 7},
#   {'term': 'ACUTE MYOCARDIAL INFARCTION', 'count': 6},
#   {'term': 'ALOPECIA', 'count': 6},
#   {'term': 'ANAPHYLACTIC SHOCK', 'count': 6},
#   {'term': 'ANASTOMOTIC LEAK', 'count': 6},
#   {'term': 'BLINDNESS UNILATERAL', 'count': 6},
#   {'term': 'BLOOD BILIRUBIN INCREASED', 'count': 6},
#   {'term': 'BODY TEMPERATURE INCREASED', 'count': 6},
#   {'term': 'CATARACT NUCLEAR', 'count': 6},
#   {'term': 'COMA', 'count': 6},
#   {'term': 'CONDITION AGGRAVATED', 'count': 6},
#   {'term': 'DIABETIC RETINAL OEDEMA', 'count': 6},
#   {'term': 'DIABETIC RETINOPATHY', 'count': 6},
#   {'term': 'DRUG EFFECT DECREASED', 'count': 6},
#   {'term': 'DYSPEPSIA', 'count': 6},
#   {'term': 'EYE DISORDER', 'count': 6},
#   {'term': 'FEELING ABNORMAL', 'count': 6},
#   {'term': 'FLUSHING', 'count': 6},
#   {'term': 'HAEMATEMESIS', 'count': 6},
#   {'term': 'HAEMORRHAGE INTRACRANIAL', 'count': 6},
#   {'term': 'HEPATIC ENCEPHALOPATHY', 'count': 6},
#   {'term': 'HEPATIC FUNCTION ABNORMAL', 'count': 6},
#   {'term': 'HICCUPS', 'count': 6},
#   {'term': 'HYPERHIDROSIS', 'count': 6},
#   {'term': 'HYPERKALAEMIA', 'count': 6},
#   {'term': 'INFLAMMATION', 'count': 6},
#   {'term': 'INFUSION RELATED REACTION', 'count': 6},
#   {'term': 'LIVER DISORDER', 'count': 6},
#   {'term': 'LUNG NEOPLASM MALIGNANT', 'count': 6},
#   {'term': 'MEMORY IMPAIRMENT', 'count': 6},
#   {'term': 'METASTASES TO BONE', 'count': 6},
#   {'term': 'OCULAR HYPERAEMIA', 'count': 6},
#   {'term': 'PANCREATITIS', 'count': 6},
#   {'term': 'PANCYTOPENIA', 'count': 6},
#   {'term': 'PNEUMONIA ASPIRATION', 'count': 6},
#   {'term': 'PNEUMONITIS', 'count': 6},
#   {'term': 'PROTEIN URINE', 'count': 6},
#   {'term': 'PULMONARY OEDEMA', 'count': 6},
#   {'term': 'RETINAL PIGMENT EPITHELIAL TEAR', 'count': 6},
#   {'term': 'RETINAL VASCULAR DISORDER', 'count': 6},
#   {'term': 'SHOCK HAEMORRHAGIC', 'count': 6},
#   {'term': 'SUDDEN DEATH', 'count': 6},
#   {'term': 'SUSPECTED TRANSMISSION OF AN INFECTIOUS AGENT VIA PRODUCT',
#    'count': 6},
#   {'term': 'ABDOMINAL PAIN LOWER', 'count': 5},
#   {'term': 'ABNORMAL BEHAVIOUR', 'count': 5},
#   {'term': 'ACNE', 'count': 5},
#   {'term': 'ACUTE RESPIRATORY DISTRESS SYNDROME', 'count': 5},
#   {'term': 'ACUTE RESPIRATORY FAILURE', 'count': 5},
#   {'term': 'AMNESIA', 'count': 5},
#   {'term': 'ANAL FISTULA', 'count': 5},
#   {'term': 'BLOOD GLUCOSE INCREASED', 'count': 5},
#   {'term': 'BLOOD LACTATE DEHYDROGENASE INCREASED', 'count': 5},
#   {'term': 'BLOOD PRESSURE DECREASED', 'count': 5},
#   {'term': 'BLOOD TEST ABNORMAL', 'count': 5},
#   {'term': 'BLOOD UREA INCREASED', 'count': 5},
#   {'term': 'BRAIN NEOPLASM', 'count': 5},
#   {'term': 'BRONCHITIS', 'count': 5},
#   {'term': 'C-REACTIVE PROTEIN INCREASED', 'count': 5},
#   {'term': 'CARDIAC FAILURE CONGESTIVE', 'count': 5},
#   {'term': 'CELLULITIS', 'count': 5},
#   {'term': 'CHEST DISCOMFORT', 'count': 5},
#   {'term': 'CHOROIDAL INFARCTION', 'count': 5},
#   {'term': 'CHRONIC OBSTRUCTIVE PULMONARY DISEASE', 'count': 5},
#   {'term': 'COAGULOPATHY', 'count': 5},
#   {'term': 'COGNITIVE DISORDER', 'count': 5},
#   {'term': 'COLON CANCER', 'count': 5},
#   {'term': 'DIARRHOEA HAEMORRHAGIC', 'count': 5},
#   {'term': 'EPILEPSY', 'count': 5},
#   {'term': 'EYE IRRITATION', 'count': 5},
#   {'term': 'EYE SWELLING', 'count': 5},
#   {'term': 'FACE OEDEMA', 'count': 5},
#   {'term': 'FEELING COLD', 'count': 5},
#   {'term': 'GASTRIC HAEMORRHAGE', 'count': 5},
#   {'term': 'GASTROENTERITIS', 'count': 5},
#   {'term': 'GASTROINTESTINAL TOXICITY', 'count': 5},
#   {'term': 'GLIOBLASTOMA MULTIFORME', 'count': 5},
#   {'term': 'HEPATIC STEATOSIS', 'count': 5},
#   {'term': 'HERPES ZOSTER', 'count': 5},
#   {'term': 'HYPERAMMONAEMIA', 'count': 5},
#   {'term': 'HYPERBILIRUBINAEMIA', 'count': 5},
#   {'term': 'HYPERSOMNIA', 'count': 5},
#   {'term': 'HYPOTHYROIDISM', 'count': 5},
#   {'term': 'HYPOXIA', 'count': 5},
#   {'term': 'ILEAL PERFORATION', 'count': 5},
#   {'term': 'LOCAL SWELLING', 'count': 5},
#   {'term': 'MELAENA', 'count': 5},
#   {'term': 'MUSCULOSKELETAL CHEST PAIN', 'count': 5},
#   {'term': 'NEPHROLITHIASIS', 'count': 5},
#   {'term': 'NEUROLOGICAL SYMPTOM', 'count': 5},
#   {'term': 'NEUTROPHIL COUNT INCREASED', 'count': 5},
#   {'term': 'PNEUMOPERITONEUM', 'count': 5},
#   {'term': 'PRODUCT USE ISSUE', 'count': 5},
#   {'term': 'PULMONARY HAEMORRHAGE', 'count': 5},
#   {'term': 'RED CELL DISTRIBUTION WIDTH INCREASED', 'count': 5},
#   {'term': 'RETINAL EXUDATES', 'count': 5},
#   {'term': 'RETINAL VEIN OCCLUSION', 'count': 5},
#   {'term': 'SEPTIC SHOCK', 'count': 5},
#   {'term': 'SKIN ULCER', 'count': 5},
#   {'term': 'SURGERY', 'count': 5},
#   {'term': 'TEMPERATURE INTOLERANCE', 'count': 5},
#   {'term': 'THERAPEUTIC RESPONSE DECREASED', 'count': 5},
#   {'term': 'TUMOUR LYSIS SYNDROME', 'count': 5},
#   {'term': 'TUMOUR NECROSIS', 'count': 5},
#   {'term': 'URINARY INCONTINENCE', 'count': 5},
#   {'term': 'URINARY RETENTION', 'count': 5},
#   {'term': 'WHEEZING', 'count': 5},
#   {'term': 'WOUND INFECTION', 'count': 5},
#   {'term': 'WOUND SECRETION', 'count': 5},
#   {'term': 'ABASIA', 'count': 4},
#   {'term': 'ABDOMINAL ABSCESS', 'count': 4},
#   {'term': 'BACTERAEMIA', 'count': 4},
#   {'term': 'BLOOD CHOLESTEROL INCREASED', 'count': 4},
#   {'term': 'BONE PAIN', 'count': 4},
#   {'term': 'CLOSTRIDIUM DIFFICILE COLITIS', 'count': 4},
#   {'term': 'COLORECTAL CANCER METASTATIC', 'count': 4},
#   {'term': 'CORONARY ARTERY DISEASE', 'count': 4},
#   {'term': 'DRUG HYPERSENSITIVITY', 'count': 4},
#   {'term': 'DUODENAL PERFORATION', 'count': 4},
#   {'term': 'DYSURIA', 'count': 4},
#   {'term': 'EATING DISORDER', 'count': 4},
#   {'term': 'ENTERITIS', 'count': 4},
#   {'term': 'ENTEROVESICAL FISTULA', 'count': 4},
#   {'term': 'ERECTILE DYSFUNCTION', 'count': 4},
#   {'term': 'EYE DISCHARGE', 'count': 4},
#   {'term': 'EYE INFECTION', 'count': 4},
#   {'term': 'FEBRILE BONE MARROW APLASIA', 'count': 4},
#   {'term': 'FLATULENCE', 'count': 4},
#   {'term': 'GASTRIC PERFORATION', 'count': 4},
#   {'term': 'GASTRIC ULCER', 'count': 4},
#   {'term': 'GASTRIC ULCER HAEMORRHAGE', 'count': 4},
#   {'term': 'GINGIVAL BLEEDING', 'count': 4},
#   {'term': 'HALLUCINATION', 'count': 4},
#   {'term': 'HEPATIC ENZYME INCREASED', 'count': 4},
#   {'term': 'HYDRONEPHROSIS', 'count': 4},
#   {'term': 'HYPERCALCAEMIA', 'count': 4},
#   {'term': 'HYPOACUSIS', 'count': 4},
#   {'term': 'HYPOPHAGIA', 'count': 4},
#   {'term': 'INFLUENZA', 'count': 4},
#   {'term': 'INFLUENZA LIKE ILLNESS', 'count': 4},
#   {'term': 'INGROWING NAIL', 'count': 4},
#   {'term': 'LARYNGITIS', 'count': 4},
#   {'term': 'LEUKOENCEPHALOPATHY', 'count': 4},
#   {'term': 'LIMB DISCOMFORT', 'count': 4},
#   {'term': 'LUNG INFILTRATION', 'count': 4},
#   {'term': 'MACULAR FIBROSIS', 'count': 4},
#   {'term': 'MASS', 'count': 4},
#   {'term': 'METAMORPHOPSIA', 'count': 4},
#   {'term': 'METASTATIC MALIGNANT MELANOMA', 'count': 4},
#   {'term': 'MIGRAINE', 'count': 4},
#   {'term': 'MYALGIA', 'count': 4},
#   {'term': 'NECROTISING FASCIITIS', 'count': 4},
#   {'term': 'NEPHROTIC SYNDROME', 'count': 4},
#   {'term': 'NEURALGIA', 'count': 4},
#   {'term': 'NEUTROPENIC SEPSIS', 'count': 4},
#   {'term': 'NO THERAPEUTIC RESPONSE', 'count': 4},
#   {'term': 'ORAL CANDIDIASIS', 'count': 4},
#   {'term': 'OROPHARYNGEAL PAIN', 'count': 4},
#   {'term': 'OSTEOARTHRITIS', 'count': 4},
#   {'term': 'PERIPHERAL SENSORY NEUROPATHY', 'count': 4},
#   {'term': 'PHOTOPSIA', 'count': 4},
#   {'term': 'PORTAL VENOUS GAS', 'count': 4},
#   {'term': 'PRODUCT CONTAMINATION', 'count': 4},
#   {'term': 'PRODUCT CONTAMINATION MICROBIAL', 'count': 4},
#   {'term': 'PULMONARY MASS', 'count': 4},
#   {'term': 'RECTAL CANCER METASTATIC', 'count': 4},
#   {'term': 'RETINAL DISORDER', 'count': 4},
#   {'term': 'SKIN EXFOLIATION', 'count': 4},
#   {'term': 'SMALL INTESTINAL PERFORATION', 'count': 4},
#   {'term': 'THROMBOPHLEBITIS', 'count': 4},
#   {'term': 'THROMBOTIC THROMBOCYTOPENIC PURPURA', 'count': 4},
#   {'term': 'TOOTHACHE', 'count': 4},
#   {'term': 'TOXICITY TO VARIOUS AGENTS', 'count': 4},
#   {'term': 'TREMOR', 'count': 4},
#   {'term': 'TUBULOINTERSTITIAL NEPHRITIS', 'count': 4},
#   {'term': 'WOUND DEHISCENCE', 'count': 4},
#   {'term': 'ABDOMINAL HERNIA', 'count': 3},
#   {'term': 'ACTIVITIES OF DAILY LIVING IMPAIRED', 'count': 3},
#   {'term': 'ACUTE HEPATIC FAILURE', 'count': 3},
#   {'term': 'ACUTE MYELOID LEUKAEMIA', 'count': 3},
#   {'term': 'AMAUROSIS', 'count': 3},
#   {'term': 'AMMONIA INCREASED', 'count': 3},
#   {'term': 'ANGIOEDEMA', 'count': 3},
#   {'term': 'AORTIC ANEURYSM', 'count': 3},
#   {'term': 'ARTERIOSPASM CORONARY', 'count': 3},
#   {'term': 'BACTERIAL INFECTION', 'count': 3},
#   {'term': 'BLOOD ALBUMIN DECREASED', 'count': 3},
#   {'term': 'BLOOD ALKALINE PHOSPHATASE INCREASED', 'count': 3},
#   {'term': 'BLOOD PRESSURE INADEQUATELY CONTROLLED', 'count': 3},
#   {'term': 'BLOOD URINE PRESENT', 'count': 3},
#   {'term': 'BRAIN HERNIATION', 'count': 3},
#   {'term': 'CARDIOGENIC SHOCK', 'count': 3},
#   {'term': 'CEREBELLAR SYNDROME', 'count': 3},
#   {'term': 'CIRCULATORY COLLAPSE', 'count': 3},
#   {'term': 'COLORECTAL CANCER', 'count': 3},
#   {'term': 'COLORECTAL CANCER STAGE III', 'count': 3},
#   {'term': 'CYST', 'count': 3},
#   {'term': 'CYSTITIS', 'count': 3},
#   {'term': 'DEAFNESS', 'count': 3},
#   {'term': 'DELIRIUM', 'count': 3},
#   {'term': 'DENTAL CARIES', 'count': 3},
#   {'term': 'DEPRESSED LEVEL OF CONSCIOUSNESS', 'count': 3},
#   {'term': 'DERMATITIS', 'count': 3},
#   {'term': 'DERMATITIS ALLERGIC', 'count': 3},
#   {'term': 'DIPLOPIA', 'count': 3},
#   {'term': 'DIVERTICULAR PERFORATION', 'count': 3},
#   {'term': 'DIVERTICULITIS', 'count': 3},
#   {'term': 'DRUG DOSE OMISSION', 'count': 3},
#   {'term': 'DYSAESTHESIA', 'count': 3},
#   {'term': 'EAR PAIN', 'count': 3},
#   {'term': 'EJECTION FRACTION DECREASED', 'count': 3},
#   {'term': 'EYE PRURITUS', 'count': 3},
#   {'term': 'FLANK PAIN', 'count': 3},
#   {'term': 'FOOT FRACTURE', 'count': 3},
#   {'term': 'GASTRITIS', 'count': 3},
#   {'term': 'GENERAL PHYSICAL CONDITION ABNORMAL', 'count': 3},
#   {'term': 'GLOSSITIS', 'count': 3},
#   {'term': 'GOUT', 'count': 3},
#   {'term': 'HAEMOTHORAX', 'count': 3},
#   {'term': 'HEART RATE DECREASED', 'count': 3},
#   {'term': 'HEPATIC CIRRHOSIS', 'count': 3},
#   {'term': 'HEPATITIS B', 'count': 3},
#   {'term': 'HEPATOTOXICITY', 'count': 3},
#   {'term': 'HIP FRACTURE', 'count': 3},
#   {'term': 'HOT FLUSH', 'count': 3},
#   {'term': 'HYPERAESTHESIA', 'count': 3},
#   {'term': 'HYPERGLYCAEMIA', 'count': 3},
#   {'term': 'HYPERTENSIVE CRISIS', 'count': 3},
#   {'term': 'HYPOALBUMINAEMIA', 'count': 3},
#   {'term': 'HYPOCALCAEMIA', 'count': 3},
#   {'term': 'INFECTIOUS PLEURAL EFFUSION', 'count': 3},
#   {'term': 'INTESTINAL ISCHAEMIA', 'count': 3},
#   {'term': 'ISCHAEMIA', 'count': 3},
#   {'term': 'JAUNDICE CHOLESTATIC', 'count': 3},
#   {'term': 'JOINT SWELLING', 'count': 3},
#   {'term': 'LABORATORY TEST ABNORMAL', 'count': 3},
#   {'term': 'LIVER FUNCTION TEST ABNORMAL', 'count': 3},
#   {'term': 'LUNG ADENOCARCINOMA', 'count': 3},
#   {'term': 'LYMPHOPENIA', 'count': 3},
#   {'term': 'MACULOPATHY', 'count': 3},
#   {'term': 'MEAN CELL HAEMOGLOBIN INCREASED', 'count': 3},
#   {'term': 'MEAN CELL VOLUME INCREASED', 'count': 3},
#   {'term': 'METASTASES TO MENINGES', 'count': 3},
#   {'term': 'MONOCYTE COUNT INCREASED', 'count': 3},
#   {'term': 'MOUTH ULCERATION', 'count': 3},
#   {'term': 'MYOPIA', 'count': 3},
#   {'term': 'NECROSIS', 'count': 3},
#   {'term': 'NEUROLOGICAL DECOMPENSATION', 'count': 3},
#   {'term': 'NODULE', 'count': 3},
#   {'term': 'OESOPHAGITIS', 'count': 3},
#   {'term': 'ONYCHOLYSIS', 'count': 3},
#   {'term': 'OSTEOMYELITIS', 'count': 3},
#   {'term': 'OSTEONECROSIS', 'count': 3},
#   {'term': 'PAIN OF SKIN', 'count': 3},
#   {'term': 'PANCREATITIS ACUTE', 'count': 3},
#   {'term': 'PARONYCHIA', 'count': 3},
#   {'term': 'PERFORMANCE STATUS DECREASED', 'count': 3},
#   {'term': 'PERIPHERAL ARTERIAL OCCLUSIVE DISEASE', 'count': 3},
#   {'term': 'PERITONEAL DISORDER', 'count': 3},
#   {'term': 'PHLEBITIS', 'count': 3},
#   {'term': 'PNEUMOTHORAX SPONTANEOUS', 'count': 3},
#   {'term': 'PORTAL HYPERTENSIVE GASTROPATHY', 'count': 3},
#   {'term': 'PORTAL VEIN THROMBOSIS', 'count': 3},
#   {'term': 'PRODUCTIVE COUGH', 'count': 3},
#   {'term': 'PUPILLARY REFLEX IMPAIRED', 'count': 3},
#   {'term': 'RASH MACULO-PAPULAR', 'count': 3},
#   {'term': 'RECTAL PERFORATION', 'count': 3},
#   {'term': 'RENAL DISORDER', 'count': 3},
#   {'term': 'RENAL FAILURE CHRONIC', 'count': 3},
#   {'term': 'RESPIRATORY DISORDER', 'count': 3},
#   {'term': 'RESPIRATORY TRACT INFECTION', 'count': 3},
#   {'term': 'RETINAL DETACHMENT', 'count': 3},
#   {'term': 'RETINAL ISCHAEMIA', 'count': 3},
#   {'term': 'SKIN IRRITATION', 'count': 3},
#   {'term': 'SKIN LESION', 'count': 3},
#   {'term': 'SLEEP APNOEA SYNDROME', 'count': 3},
#   {'term': 'SLEEP DISORDER', 'count': 3},
#   {'term': 'SWOLLEN TONGUE', 'count': 3},
#   {'term': 'TETANY', 'count': 3},
#   {'term': 'TINNITUS', 'count': 3},
#   {'term': 'TONGUE ULCERATION', 'count': 3},
#   {'term': 'TRANSAMINASES INCREASED', 'count': 3},
#   {'term': 'TUMOUR PAIN', 'count': 3},
#   {'term': 'ULCER', 'count': 3},
#   {'term': 'VIITH NERVE PARALYSIS', 'count': 3},
#   {'term': 'VISUAL FIELD DEFECT', 'count': 3},
#   {'term': 'VITREOUS DETACHMENT', 'count': 3},
#   {'term': 'WHITE BLOOD CELL COUNT ABNORMAL', 'count': 3},
#   {'term': 'ACUTE ABDOMEN', 'count': 2},
#   {'term': 'ADENOCARCINOMA', 'count': 2},
#   {'term': 'AGGRESSION', 'count': 2},
#   {'term': 'ALLODYNIA', 'count': 2},
#   {'term': 'ANAL ABSCESS', 'count': 2},
#   {'term': 'ANAL FISSURE', 'count': 2},
#   {'term': 'ANAL HAEMORRHAGE', 'count': 2},
#   {'term': 'ANAPHYLACTIC REACTION', 'count': 2},
#   {'term': 'ANASTOMOTIC COMPLICATION', 'count': 2},
#   {'term': 'ANGINA PECTORIS', 'count': 2},
#   {'term': 'ANORECTAL VARICES', 'count': 2},
#   {'term': 'APHAGIA', 'count': 2},
#   {'term': 'APHONIA', 'count': 2},
#   {'term': 'APHTHOUS STOMATITIS', 'count': 2},
#   {'term': 'APPENDICITIS', 'count': 2},
#   {'term': 'ARTERIOSCLEROSIS', 'count': 2},
#   {'term': 'ASTHENOPIA', 'count': 2},
#   {'term': 'ATAXIA', 'count': 2},
#   {'term': 'ATELECTASIS', 'count': 2},
#   {'term': 'BACTERIAL TEST POSITIVE', 'count': 2},
#   {'term': 'BALANOPOSTHITIS', 'count': 2},
#   {'term': 'BILE DUCT OBSTRUCTION', 'count': 2},
#   {'term': 'BLADDER PERFORATION', 'count': 2},
#   {'term': 'BLOOD BLISTER', 'count': 2},
#   {'term': 'BLOOD CREATININE DECREASED', 'count': 2},
#   {'term': 'BLOOD POTASSIUM INCREASED', 'count': 2},
#   {'term': 'BODY TEMPERATURE DECREASED', 'count': 2},
#   {'term': 'BONE DISORDER', 'count': 2},
#   {'term': 'BRADYCARDIA', 'count': 2},
#   {'term': 'BRAIN NEOPLASM MALIGNANT', 'count': 2},
#   {'term': 'BRONCHOSPASM', 'count': 2},
#   {'term': 'CACHEXIA', 'count': 2},
#   {'term': 'CALCULUS URETERIC', 'count': 2},
#   {'term': 'CANCER PAIN', 'count': 2},
#   {'term': 'CANDIDA INFECTION', 'count': 2},
#   {'term': 'CARDIAC DISORDER', 'count': 2},
#   {'term': 'CARDIAC FAILURE ACUTE', 'count': 2},
#   {'term': 'CARDIOMYOPATHY', 'count': 2},
#   {'term': 'CARDIOTOXICITY', 'count': 2},
#   {'term': 'CEREBRAL ATROPHY', 'count': 2},
#   {'term': 'CEREBRAL ISCHAEMIA', 'count': 2},
#   {'term': 'CEREBRAL THROMBOSIS', 'count': 2},
#   {'term': 'CEREBROVASCULAR DISORDER', 'count': 2},
#   {'term': 'CHOLECYSTITIS', 'count': 2},
#   {'term': 'CHOLECYSTITIS ACUTE', 'count': 2},
#   {'term': 'CHOLESTASIS', 'count': 2},
#   {'term': 'COLON CANCER STAGE IV', 'count': 2},
#   {'term': 'COMA SCALE ABNORMAL', 'count': 2},
#   {'term': 'COMPLETED SUICIDE', 'count': 2},
#   {'term': 'CONJUNCTIVAL HAEMORRHAGE', 'count': 2},
#   {'term': 'CONJUNCTIVITIS', 'count': 2},
#   {'term': 'COORDINATION ABNORMAL', 'count': 2},
#   {'term': 'CYTOMEGALOVIRUS ENTEROCOLITIS', 'count': 2},
#   {'term': 'CYTOMEGALOVIRUS TEST POSITIVE', 'count': 2},
#   {'term': 'DEPRESSION', 'count': 2},
#   {'term': 'DEVICE DISLOCATION', 'count': 2},
#   {'term': 'DIABETES INSIPIDUS', 'count': 2},
#   {'term': 'DIABETES MELLITUS', 'count': 2},
#   {'term': 'DIABETIC HYPEROSMOLAR COMA', 'count': 2},
#   {'term': 'DISEASE RECURRENCE', 'count': 2},
#   {'term': 'DIVERTICULUM INTESTINAL', 'count': 2},
#   {'term': 'DRUG EFFECT INCOMPLETE', 'count': 2},
#   {'term': 'DRUG RESISTANCE', 'count': 2},
#   {'term': 'DRUG WITHDRAWAL SYNDROME', 'count': 2},
#   {'term': 'DRY EYE', 'count': 2},
#   {'term': 'DYSKINESIA', 'count': 2},
#   {'term': 'ELECTROLYTE IMBALANCE', 'count': 2},
#   {'term': 'EMOTIONAL DISTRESS', 'count': 2},
#   {'term': 'EMPHYSEMA', 'count': 2},
#   {'term': 'ENTEROCOLITIS', 'count': 2},
#   {'term': 'ESSENTIAL HYPERTENSION', 'count': 2},
#   {'term': 'EXPOSED BONE IN JAW', 'count': 2},
#   {'term': 'EYE INFLAMMATION', 'count': 2},
#   {'term': 'EYE OEDEMA', 'count': 2},
#   {'term': 'FAECALOMA', 'count': 2},
#   {'term': 'FEELING HOT', 'count': 2},
#   {'term': 'FISTULA', 'count': 2},
#   {'term': 'FLAT AFFECT', 'count': 2},
#   {'term': 'FLUID OVERLOAD', 'count': 2},
#   {'term': 'FOCAL SEGMENTAL GLOMERULOSCLEROSIS', 'count': 2},
#   {'term': 'FUNGAL INFECTION', 'count': 2},
#   {'term': 'GALLBLADDER DISORDER', 'count': 2},
#   {'term': 'GAMMA-GLUTAMYLTRANSFERASE INCREASED', 'count': 2},
#   {'term': 'GASTRIC DISORDER', 'count': 2},
#   {'term': 'GASTROENTERITIS RADIATION', 'count': 2},
#   {'term': 'GASTROINTESTINAL MOTILITY DISORDER', 'count': 2},
#   {'term': 'GASTROINTESTINAL NECROSIS', 'count': 2},
#   {'term': 'GENERALISED OEDEMA', 'count': 2},
#   {'term': 'GENITAL HERPES ZOSTER', 'count': 2},
#   {'term': 'GLOMERULONEPHRITIS', 'count': 2},
#   {'term': 'GRANULOMA', 'count': 2},
#   {'term': 'HAEMATOMA', 'count': 2},
#   {'term': 'HAEMORRHAGIC DIATHESIS', 'count': 2},
#   {'term': 'HAEMORRHOIDS', 'count': 2},
#   {'term': 'HEPATIC HAEMORRHAGE', 'count': 2},
#   {'term': 'HEPATITIS', 'count': 2},
#   {'term': 'HEPATORENAL SYNDROME', 'count': 2},
#   {'term': 'HYDROCEPHALUS', 'count': 2},
#   {'term': 'HYPERLIPIDAEMIA', 'count': 2},
#   {'term': 'HYPERNATRAEMIA', 'count': 2},
#   {'term': 'HYPERTHERMIA', 'count': 2},
#   {'term': 'HYPERTHYROIDISM', 'count': 2},
#   {'term': 'HYPERTRIGLYCERIDAEMIA', 'count': 2},
#   {'term': 'HYPOVOLAEMIC SHOCK', 'count': 2},
#   {'term': 'ILL-DEFINED DISORDER', 'count': 2},
#   {'term': 'IMMUNE THROMBOCYTOPENIC PURPURA', 'count': 2},
#   {'term': 'INAPPROPRIATE SCHEDULE OF DRUG ADMINISTRATION', 'count': 2},
#   {'term': 'INCISION SITE INFECTION', 'count': 2},
#   {'term': 'INCREASED TENDENCY TO BRUISE', 'count': 2},
#   {'term': 'INJECTION SITE HAEMORRHAGE', 'count': 2},
#   {'term': 'IRON DEFICIENCY ANAEMIA', 'count': 2},
#   {'term': 'ISCHAEMIC STROKE', 'count': 2},
#   {'term': 'JOINT STIFFNESS', 'count': 2},
#   {'term': 'KLEBSIELLA INFECTION', 'count': 2},
#   {'term': 'LEUKOCYTOCLASTIC VASCULITIS', 'count': 2},
#   {'term': 'LIMB INJURY', 'count': 2},
#   {'term': 'LOWER GASTROINTESTINAL HAEMORRHAGE', 'count': 2},
#   {'term': 'LUNG CANCER METASTATIC', 'count': 2},
#   {'term': 'LYMPHADENOPATHY', 'count': 2},
#   {'term': 'LYMPHANGITIS', 'count': 2},
#   {'term': 'MACULAR ISCHAEMIA', 'count': 2},
#   {'term': 'MALNUTRITION', 'count': 2},
#   {'term': 'MECHANICAL ILEUS', 'count': 2},
#   {'term': 'MEDICATION ERROR', 'count': 2},
#   {'term': 'MENTAL IMPAIRMENT', 'count': 2},
#   {'term': 'MESENTERIC ARTERY THROMBOSIS', 'count': 2},
#   {'term': 'METABOLIC ENCEPHALOPATHY', 'count': 2},
#   {'term': 'METASTASES TO LYMPH NODES', 'count': 2},
#   {'term': 'METASTASES TO PERITONEUM', 'count': 2},
#   {'term': 'METASTATIC RENAL CELL CARCINOMA', 'count': 2},
#   {'term': 'MOBILITY DECREASED', 'count': 2},
#   {'term': 'MUCOSAL HAEMORRHAGE', 'count': 2},
#   {'term': 'MUCOSAL INFECTION', 'count': 2},
#   {'term': 'MUCOUS MEMBRANE DISORDER', 'count': 2},
#   {'term': 'MUSCLE DISORDER', 'count': 2},
#   {'term': 'MUSCULOSKELETAL DISCOMFORT', 'count': 2},
#   {'term': 'MYELODYSPLASTIC SYNDROME', 'count': 2},
#   {'term': 'MYOCARDIAL ISCHAEMIA', 'count': 2},
#   {'term': 'NASAL CONGESTION', 'count': 2},
#   {'term': 'NERVOUS SYSTEM DISORDER', 'count': 2},
#   {'term': 'NON-SMALL CELL LUNG CANCER', 'count': 2},
#   {'term': 'NON-SMALL CELL LUNG CANCER METASTATIC', 'count': 2},
#   {'term': 'NON-SMALL CELL LUNG CANCER RECURRENT', 'count': 2},
#   {'term': 'NORMOCHROMIC NORMOCYTIC ANAEMIA', 'count': 2},
#   {'term': 'OBSTRUCTIVE UROPATHY', 'count': 2},
#   {'term': 'OESOPHAGEAL CANCER METASTATIC', 'count': 2},
#   {'term': 'OESOPHAGEAL PAIN', 'count': 2},
#   {'term': 'ORAL PAIN', 'count': 2},
#   {'term': 'PALLOR', 'count': 2},
#   {'term': 'PARALYSIS', 'count': 2},
#   {'term': 'PARTIAL SEIZURES', 'count': 2},
#   {'term': 'PERICARDIAL EFFUSION', 'count': 2},
#   {'term': 'PERIORBITAL OEDEMA', 'count': 2},
#   {'term': 'PERIPHERAL COLDNESS', 'count': 2},
#   {'term': 'PERIPHERAL ISCHAEMIA', 'count': 2},
#   {'term': 'PERIPHERAL SWELLING', 'count': 2},
#   {'term': 'PLATELET TRANSFUSION', 'count': 2},
#   {'term': 'POOR QUALITY SLEEP', 'count': 2},
#   {'term': 'POOR VENOUS ACCESS', 'count': 2},
#   {'term': 'POSTOPERATIVE WOUND COMPLICATION', 'count': 2},
#   {'term': 'POSTOPERATIVE WOUND INFECTION', 'count': 2},
#   {'term': 'PRIAPISM', 'count': 2},
#   {'term': 'PROCEDURAL COMPLICATION', 'count': 2},
#   {'term': 'PROCTALGIA', 'count': 2},
#   {'term': 'PROSTATITIS', 'count': 2},
#   {'term': 'PULMONARY ALVEOLAR HAEMORRHAGE', 'count': 2},
#   {'term': 'PULMONARY GRANULOMA', 'count': 2},
#   {'term': 'PULMONARY INFARCTION', 'count': 2},
#   {'term': 'PURPURA', 'count': 2},
#   {'term': 'RASH MACULAR', 'count': 2},
#   {'term': 'READING DISORDER', 'count': 2},
#   {'term': 'RETINAL ARTERY EMBOLISM', 'count': 2},
#   {'term': 'RETINAL DEGENERATION', 'count': 2},
#   {'term': 'RETINAL TEAR', 'count': 2},
#   {'term': 'RETROPERITONEAL ABSCESS', 'count': 2},
#   {'term': 'RHABDOMYOLYSIS', 'count': 2},
#   {'term': 'RHINORRHOEA', 'count': 2},
#   {'term': 'ROTATOR CUFF SYNDROME', 'count': 2},
#   {'term': 'SCAR', 'count': 2},
#   {'term': 'SCROTAL PAIN', 'count': 2},
#   {'term': 'SHOCK', 'count': 2},
#   {'term': 'SINUS BRADYCARDIA', 'count': 2},
#   {'term': 'SINUSITIS', 'count': 2},
#   {'term': 'SKIN FRAGILITY', 'count': 2},
#   {'term': 'SKIN STRIAE', 'count': 2},
#   {'term': 'SUBCLAVIAN VEIN THROMBOSIS', 'count': 2},
#   {'term': 'SUBRETINAL FLUID', 'count': 2},
#   {'term': 'SWELLING', 'count': 2},
#   {'term': 'TERMINAL STATE', 'count': 2},
#   {'term': 'TESTICULAR PAIN', 'count': 2},
#   {'term': 'THROMBOTIC MICROANGIOPATHY', 'count': 2},
#   {'term': 'THYROID DISORDER', 'count': 2},
#   {'term': 'TONGUE HAEMORRHAGE', 'count': 2},
#   {'term': 'TOOTH FRACTURE', 'count': 2},
#   {'term': 'TOXIC SKIN ERUPTION', 'count': 2},
#   {'term': 'TREATMENT FAILURE', 'count': 2},
#   {'term': 'TREATMENT NONCOMPLIANCE', 'count': 2},
#   {'term': 'TROPONIN INCREASED', 'count': 2},
#   {'term': 'TUMOUR ASSOCIATED FEVER', 'count': 2},
#   {'term': 'TYPE 2 DIABETES MELLITUS', 'count': 2},
#   {'term': 'UNEVALUABLE EVENT', 'count': 2},
#   {'term': 'UROSEPSIS', 'count': 2},
#   {'term': 'URTICARIA', 'count': 2},
#   {'term': 'UVEITIS', 'count': 2},
#   {'term': 'VARICOSE VEIN', 'count': 2},
#   {'term': 'VASCULITIS', 'count': 2},
#   {'term': 'VENOOCCLUSIVE LIVER DISEASE', 'count': 2},
#   {'term': 'VERTIGO', 'count': 2},
#   {'term': 'VITRITIS', 'count': 2},
#   {'term': 'WEIGHT FLUCTUATION', 'count': 2},
#   {'term': 'ABDOMINAL CAVITY DRAINAGE', 'count': 1},
#   {'term': 'ABDOMINAL INFECTION', 'count': 1},
#   {'term': 'ABDOMINAL MASS', 'count': 1},
#   {'term': 'ABDOMINAL RIGIDITY', 'count': 1},
#   {'term': 'ABDOMINAL WALL NEOPLASM', 'count': 1},
#   {'term': 'ABNORMAL FAECES', 'count': 1},
#   {'term': 'ABNORMAL SENSATION IN EYE', 'count': 1},
#   {'term': 'ABSCESS JAW', 'count': 1},
#   {'term': 'ACCIDENTAL OVERDOSE', 'count': 1},
#   {'term': 'ACQUIRED PHIMOSIS', 'count': 1},
#   {'term': 'ACUTE CORONARY SYNDROME', 'count': 1},
#   {'term': 'ACUTE PULMONARY OEDEMA', 'count': 1},
#   {'term': 'ADENOCARCINOMA OF COLON', 'count': 1},
#   {'term': 'AGE-RELATED MACULAR DEGENERATION', 'count': 1},
#   {'term': 'AGORAPHOBIA', 'count': 1},
#   {'term': 'ALTERED VISUAL DEPTH PERCEPTION', 'count': 1},
#   {'term': 'ANAEMIA MACROCYTIC', 'count': 1},
#   {'term': 'ANAEMIA OF MALIGNANT DISEASE', 'count': 1},
#   {'term': 'ANAL SPASM', 'count': 1},
#   {'term': 'ANEURYSM', 'count': 1},
#   {'term': 'ANGIODYSPLASIA', 'count': 1},
#   {'term': 'ANGIOPATHY', 'count': 1},
#   {'term': 'ANGIOTENSIN CONVERTING ENZYME DECREASED', 'count': 1},
#   {'term': 'ANION GAP INCREASED', 'count': 1},
#   {'term': 'ANTERIOR CHAMBER CELL', 'count': 1},
#   {'term': 'ANTERIOR CHAMBER INFLAMMATION', 'count': 1},
#   {'term': 'AORTIC ARTERIOSCLEROSIS', 'count': 1},
#   {'term': 'AORTIC CALCIFICATION', 'count': 1},
#   {'term': 'AORTIC DISORDER', 'count': 1},
#   {'term': 'AORTIC DISSECTION', 'count': 1},
#   {'term': 'AORTIC VALVE INCOMPETENCE', 'count': 1},
#   {'term': 'AORTIC VALVE STENOSIS', 'count': 1},
#   {'term': 'APHTHOUS ULCER', 'count': 1},
#   {'term': 'APPETITE DISORDER', 'count': 1},
#   {'term': 'AREFLEXIA', 'count': 1},
#   {'term': 'ARRHYTHMIA', 'count': 1},
#   {'term': 'ARTERIAL HAEMORRHAGE', 'count': 1},
#   {'term': 'ARTERIAL INJURY', 'count': 1},
#   {'term': 'ARTERIAL RUPTURE', 'count': 1},
#   {'term': 'ARTERIAL SPASM', 'count': 1},
#   {'term': 'ARTERIAL STENOSIS', 'count': 1},
#   {'term': 'ARTHRITIS', 'count': 1},
#   {'term': 'ARTHRITIS INFECTIVE', 'count': 1},
#   {'term': 'ARTHROPOD BITE', 'count': 1},
#   {'term': 'ASPIRATION', 'count': 1},
#   {'term': 'ATRIAL FLUTTER', 'count': 1},
#   {'term': 'ATRIAL THROMBOSIS', 'count': 1},
#   {'term': 'ATRIOVENTRICULAR BLOCK COMPLETE', 'count': 1},
#   {'term': 'ATYPICAL PNEUMONIA', 'count': 1},
#   {'term': 'AUTOIMMUNE HAEMOLYTIC ANAEMIA', 'count': 1},
#   {'term': 'BACK INJURY', 'count': 1},
#   {'term': 'BACTERIAL DISEASE CARRIER', 'count': 1},
#   {'term': 'BASAL CELL CARCINOMA', 'count': 1},
#   {'term': 'BEDRIDDEN', 'count': 1},
#   {'term': 'BENIGN PROSTATIC HYPERPLASIA', 'count': 1},
#   {'term': 'BILE DUCT NECROSIS', 'count': 1},
#   {'term': 'BILIARY DILATATION', 'count': 1},
#   {'term': 'BILIARY SEPSIS', 'count': 1},
#   {'term': 'BILOMA', 'count': 1},
#   {'term': 'BLADDER ADENOCARCINOMA RECURRENT', 'count': 1},
#   {'term': 'BLADDER ADENOCARCINOMA STAGE UNSPECIFIED', 'count': 1},
#   {'term': 'BLADDER CANCER', 'count': 1},
#   {'term': 'BLADDER NEOPLASM', 'count': 1},
#   {'term': 'BLOOD CHLORIDE DECREASED', 'count': 1},
#   {'term': 'BLOOD CREATINE PHOSPHOKINASE INCREASED', 'count': 1},
#   {'term': 'BLOOD CREATININE ABNORMAL', 'count': 1},
#   {'term': 'BLOOD IRON DECREASED', 'count': 1},
#   {'term': 'BLOOD KETONE BODY INCREASED', 'count': 1},
#   {'term': 'BLOOD OSMOLARITY DECREASED', 'count': 1},
#   {'term': 'BLOOD PHOSPHORUS ABNORMAL', 'count': 1},
#   {'term': 'BLOOD PHOSPHORUS DECREASED', 'count': 1},
#   {'term': 'BLOOD PRESSURE ABNORMAL', 'count': 1},
#   {'term': 'BLOOD PRESSURE DIASTOLIC DECREASED', 'count': 1},
#   {'term': 'BLOOD PRESSURE FLUCTUATION', 'count': 1},
#   {'term': 'BLOOD PRESSURE SYSTOLIC INCREASED', 'count': 1},
#   {'term': 'BLOOD SODIUM DECREASED', 'count': 1},
#   {'term': 'BLOOD TRIGLYCERIDES INCREASED', 'count': 1},
#   {'term': 'BLOOD URIC ACID INCREASED', 'count': 1},
#   {'term': 'BONE CANCER', 'count': 1},
#   {'term': 'BONE LESION', 'count': 1},
#   {'term': 'BONE MARROW DISORDER', 'count': 1},
#   {'term': 'BONE MARROW TOXICITY', 'count': 1},
#   {'term': 'BOWEL MOVEMENT IRREGULARITY', 'count': 1},
#   {'term': 'BRAIN ABSCESS', 'count': 1},
#   {'term': 'BRAIN MASS', 'count': 1},
#   {'term': 'BREAKTHROUGH PAIN', 'count': 1},
#   {'term': 'BREAST CANCER', 'count': 1},
#   {'term': 'BREAST CANCER MALE', 'count': 1},
#   {'term': 'BREATH SOUNDS ABNORMAL', 'count': 1},
#   {'term': 'BRONCHIAL FISTULA', 'count': 1},
#   {'term': 'BRONCHIAL HAEMORRHAGE', 'count': 1},
#   {'term': 'BRONCHITIS VIRAL', 'count': 1},
#   {'term': 'BRONCHOPLEURAL FISTULA', 'count': 1},
#   {'term': 'BRONCHOPNEUMONIA', 'count': 1},
#   {'term': 'BRONCHOPNEUMOPATHY', 'count': 1},
#   {'term': 'BRUNNER^S GLAND HYPERPLASIA', 'count': 1},
#   {'term': 'BURNING SENSATION', 'count': 1},
#   {'term': 'CAPILLARY FRAGILITY', 'count': 1},
#   {'term': 'CARBOHYDRATE ANTIGEN 19-9 INCREASED', 'count': 1},
#   {'term': 'CARCINOEMBRYONIC ANTIGEN INCREASED', 'count': 1},
#   {'term': 'CARCINOID TUMOUR', 'count': 1},
#   {'term': 'CARDIAC AMYLOIDOSIS', 'count': 1},
#   {'term': 'CARDIAC DYSFUNCTION', 'count': 1},
#   {'term': 'CARDIAC TAMPONADE', 'count': 1},
#   {'term': 'CARDIAC VALVE DISEASE', 'count': 1},
#   {'term': 'CARDIOVASCULAR DISORDER', 'count': 1},
#   {'term': 'CAROTID ARTERY OCCLUSION', 'count': 1},
#   {'term': 'CAROTID ARTERY STENOSIS', 'count': 1},
#   {'term': 'CATARACT CORTICAL', 'count': 1},
#   {'term': 'CATARACT OPERATION', 'count': 1},
#   {'term': 'CATARACT SUBCAPSULAR', 'count': 1},
#   {'term': 'CATHETER SITE ERYTHEMA', 'count': 1},
#   {'term': 'CELL MARKER INCREASED', 'count': 1},
#   {'term': 'CENTRAL NERVOUS SYSTEM INFECTION', 'count': 1},
#   {'term': 'CENTRAL NERVOUS SYSTEM LESION', 'count': 1},
#   {'term': 'CENTRAL NERVOUS SYSTEM NECROSIS', 'count': 1},
#   {'term': 'CEREBELLAR ATAXIA', 'count': 1},
#   {'term': 'CEREBELLAR INFARCTION', 'count': 1},
#   {'term': 'CEREBELLAR TUMOUR', 'count': 1},
#   {'term': 'CEREBRAL DISORDER', 'count': 1},
#   {'term': 'CEREBRAL HAEMATOMA', 'count': 1},
#   {'term': 'CEREBRAL HYPOPERFUSION', 'count': 1},
#   {'term': 'CEREBRAL SMALL VESSEL ISCHAEMIC DISEASE', 'count': 1},
#   {'term': 'CEREBROSPINAL FLUID LEAKAGE', 'count': 1},
#   {'term': 'CERVICAL VERTEBRAL FRACTURE', 'count': 1},
#   {'term': 'CHANGE OF BOWEL HABIT', 'count': 1},
#   {'term': 'CHEILITIS', 'count': 1},
#   {'term': 'CHEILOSIS', 'count': 1},
#   {'term': 'CHEST X-RAY ABNORMAL', 'count': 1},
#   {'term': 'CHLAMYDIA TEST POSITIVE', 'count': 1},
#   {'term': 'CHOLANGIOCARCINOMA', 'count': 1},
#   {'term': 'CHOLECYSTITIS CHRONIC', 'count': 1},
#   {'term': 'CHOLELITHIASIS', 'count': 1},
#   {'term': 'CHORIORETINAL DISORDER', 'count': 1},
#   {'term': 'CHOROID PLEXUS CARCINOMA', 'count': 1},
#   {'term': 'CHOROIDAL DETACHMENT', 'count': 1},
#   {'term': 'CHOROIDAL NEOVASCULARISATION', 'count': 1},
#   {'term': 'CHOROIDAL RUPTURE', 'count': 1},
#   {'term': 'CHROMATURIA', 'count': 1},
#   {'term': 'CHRONIC HEPATITIS C', 'count': 1},
#   {'term': 'CHRONIC KIDNEY DISEASE', 'count': 1},
#   {'term': 'CILIARY BODY DISORDER', 'count': 1},
#   {'term': 'CILIARY HYPERAEMIA', 'count': 1},
#   {'term': 'CLAVICLE FRACTURE', 'count': 1},
#   {'term': 'CLOSTRIDIUM TEST POSITIVE', 'count': 1},
#   {'term': 'COAGULATION TIME PROLONGED', 'count': 1},
#   {'term': 'COLD SWEAT', 'count': 1},
#   {'term': 'COLECTOMY', 'count': 1},
#   {'term': 'COLITIS ISCHAEMIC', 'count': 1},
#   {'term': 'COLON CANCER RECURRENT', 'count': 1},
#   {'term': 'COLONIC FISTULA', 'count': 1},
#   {'term': 'COLOSTOMY', 'count': 1},
#   {'term': 'COLOSTOMY CLOSURE', 'count': 1},
#   {'term': 'CONCUSSION', 'count': 1},
#   {'term': 'CONGESTIVE CARDIOMYOPATHY', 'count': 1},
#   {'term': 'CORNEAL DISORDER', 'count': 1},
#   {'term': 'CORNEAL OEDEMA', 'count': 1},
#   {'term': 'CORONARY ANGIOPLASTY', 'count': 1},
#   {'term': 'CORONARY ARTERIAL STENT INSERTION', 'count': 1},
#   {'term': 'CORONARY ARTERY BYPASS', 'count': 1},
#   {'term': 'COSTOCHONDRITIS', 'count': 1},
#   {'term': 'CRANIOCEREBRAL INJURY', 'count': 1},
#   {'term': 'CROHN^S DISEASE', 'count': 1},
#   {'term': 'CYCLOPLEGIA', 'count': 1},
#   {'term': 'CYTOPENIA', 'count': 1},
#   {'term': 'DEAFNESS UNILATERAL', 'count': 1},
#   {'term': 'DECREASED ACTIVITY', 'count': 1},
#   {'term': 'DECREASED INTEREST', 'count': 1},
#   {'term': 'DECUBITUS ULCER', 'count': 1},
#   {'term': 'DEFORMITY', 'count': 1},
#   {'term': 'DEMENTIA', 'count': 1},
#   {'term': 'DEPRESSED MOOD', 'count': 1},
#   {'term': 'DERMAL CYST', 'count': 1},
#   {'term': 'DERMATITIS BULLOUS', 'count': 1},
#   {'term': 'DERMATOSIS', 'count': 1},
#   {'term': 'DETACHMENT OF RETINAL PIGMENT EPITHELIUM', 'count': 1},
#   {'term': 'DEVICE BREAKAGE', 'count': 1},
#   {'term': 'DEVICE MALFUNCTION', 'count': 1},
#   {'term': 'DEVICE OCCLUSION', 'count': 1},
#   {'term': 'DEVICE RELATED INFECTION', 'count': 1},
#   {'term': 'DIABETES MELLITUS INADEQUATE CONTROL', 'count': 1},
#   {'term': 'DIABETIC FOOT', 'count': 1},
#   {'term': 'DIABETIC KETOACIDOSIS', 'count': 1},
#   {'term': 'DILATATION VENTRICULAR', 'count': 1},
#   {'term': 'DISCOMFORT', 'count': 1},
#   {'term': 'DISORIENTATION', 'count': 1},
#   {'term': 'DIVERTICULUM', 'count': 1},
#   {'term': 'DIVERTICULUM INTESTINAL HAEMORRHAGIC', 'count': 1},
#   {'term': 'DONOR LEUKOCYTE INFUSION', 'count': 1},
#   {'term': 'DRUG ERUPTION', 'count': 1},
#   {'term': 'DRUG INTOLERANCE', 'count': 1},
#   {'term': 'DRUG LEVEL INCREASED', 'count': 1},
#   {'term': 'DRUG TOLERANCE', 'count': 1},
#   {'term': 'DRUG-INDUCED LIVER INJURY', 'count': 1},
#   {'term': 'DUODENAL ULCER PERFORATION', 'count': 1},
#   {'term': 'DYSCHEZIA', 'count': 1},
#   {'term': 'DYSGRAPHIA', 'count': 1},
#   {'term': 'EAR DISCOMFORT', 'count': 1},
#   {'term': 'EAR INFECTION', 'count': 1},
#   {'term': 'EAR SWELLING', 'count': 1},
#   {'term': 'ECCHYMOSIS', 'count': 1},
#   {'term': 'EFFUSION', 'count': 1},
#   {'term': 'ELECTROCARDIOGRAM ABNORMAL', 'count': 1},
#   {'term': 'ELECTROCARDIOGRAM T WAVE PEAKED', 'count': 1},
#   {'term': 'EMBOLISM VENOUS', 'count': 1},
#   {'term': 'EMPYEMA', 'count': 1},
#   {'term': 'ENCEPHALITIS', 'count': 1},
#   {'term': 'ENTERITIS INFECTIOUS', 'count': 1},
#   {'term': 'ENTEROCUTANEOUS FISTULA', 'count': 1},
#   {'term': 'EOSINOPHIL COUNT INCREASED', 'count': 1},
#   {'term': 'EPIGASTRIC DISCOMFORT', 'count': 1},
#   {'term': 'ERYSIPELAS', 'count': 1},
#   {'term': 'ERYTHROPOIESIS ABNORMAL', 'count': 1},
#   {'term': 'ESCHERICHIA SEPSIS', 'count': 1},
#   {'term': 'ESCHERICHIA TEST POSITIVE', 'count': 1},
#   {'term': 'ESSENTIAL THROMBOCYTHAEMIA', 'count': 1},
#   {'term': 'EXCORIATION', 'count': 1},
#   {'term': 'EXERCISE TOLERANCE DECREASED', 'count': 1},
#   {'term': 'EXFOLIATIVE RASH', 'count': 1},
#   {'term': 'EXPOSURE VIA DIRECT CONTACT', 'count': 1},
#   {'term': 'EXTRAVASATION', 'count': 1},
#   {'term': 'EXTREMITY NECROSIS', 'count': 1},
#   {'term': 'EYE INFECTION SYPHILITIC', 'count': 1},
#   {'term': 'EYE INFECTION VIRAL', 'count': 1},
#   {'term': 'EYE INJURY', 'count': 1},
#   {'term': 'EYELID INFECTION', 'count': 1},
#   {'term': 'EYELID MARGIN CRUSTING', 'count': 1},
#   {'term': 'FAECAL INCONTINENCE', 'count': 1},
#   {'term': 'FAECALURIA', 'count': 1},
#   {'term': 'FAECES DISCOLOURED', 'count': 1},
#   {'term': 'FAILURE TO THRIVE', 'count': 1},
#   {'term': 'FASCIITIS', 'count': 1},
#   {'term': 'FAT NECROSIS', 'count': 1},
#   {'term': 'FEEDING DISORDER', 'count': 1},
#   {'term': 'FEMUR FRACTURE', 'count': 1},
#   {'term': 'FINGERPRINT LOSS', 'count': 1},
#   {'term': 'FISTULA OF SMALL INTESTINE', 'count': 1},
#   {'term': 'FLOPPY EYELID SYNDROME', 'count': 1},
#   {'term': 'FLUID RETENTION', 'count': 1},
#   {'term': 'FOETAL MALFORMATION', 'count': 1},
#   {'term': 'FOLLICULITIS', 'count': 1},
#   {'term': 'FOREIGN BODY SENSATION IN EYES', 'count': 1},
#   {'term': 'FRUSTRATION', 'count': 1},
#   {'term': 'FULL BLOOD COUNT ABNORMAL', 'count': 1},
#   {'term': 'GALLBLADDER OPERATION', 'count': 1},
#   {'term': 'GANGRENE', 'count': 1},
#   {'term': 'GAS GANGRENE', 'count': 1},
#   {'term': 'GASTRECTOMY', 'count': 1},
#   {'term': 'GASTRIC DILATATION', 'count': 1},
#   {'term': 'GASTRIC OPERATION', 'count': 1},
#   {'term': 'GASTROINTESTINAL ANASTOMOTIC LEAK', 'count': 1},
#   {'term': 'GASTROINTESTINAL FISTULA', 'count': 1},
#   {'term': 'GASTROINTESTINAL HYPOMOTILITY', 'count': 1},
#   {'term': 'GASTROINTESTINAL INFLAMMATION', 'count': 1},
#   {'term': 'GASTROINTESTINAL NEOPLASM', 'count': 1},
#   {'term': 'GASTROINTESTINAL OBSTRUCTION', 'count': 1},
#   {'term': 'GASTROINTESTINAL PAIN', 'count': 1},
#   {'term': 'GENERALISED TONIC-CLONIC SEIZURE', 'count': 1},
#   {'term': 'GINGIVAL DISORDER', 'count': 1},
#   {'term': 'GINGIVAL ERYTHEMA', 'count': 1},
#   {'term': 'GINGIVAL INFLAMMATION', 'count': 1},
#   {'term': 'GINGIVAL RECESSION', 'count': 1},
#   {'term': 'GLAUCOMA', 'count': 1},
#   {'term': 'GLOMERULONEPHRITIS MEMBRANOPROLIFERATIVE', 'count': 1},
#   {'term': 'GLOSSODYNIA', 'count': 1},
#   {'term': 'GRAND MAL CONVULSION', 'count': 1},
#   {'term': 'GRANULOMATOUS LIVER DISEASE', 'count': 1},
#   {'term': 'GROIN PAIN', 'count': 1},
#   {'term': 'GYNAECOMASTIA', 'count': 1},
#   {'term': 'HAEMATOCRIT INCREASED', 'count': 1},
#   {'term': 'HAEMODIALYSIS', 'count': 1},
#   {'term': 'HAEMORRHAGE URINARY TRACT', 'count': 1},
#   {'term': 'HAEMORRHAGIC ANAEMIA', 'count': 1},
#   {'term': 'HAEMORRHAGIC DISORDER', 'count': 1},
#   {'term': 'HAEMORRHOIDAL HAEMORRHAGE', 'count': 1},
#   {'term': 'HEARING IMPAIRED', 'count': 1},
#   {'term': 'HEART RATE IRREGULAR', 'count': 1},
#   {'term': 'HEMIANOPIA', 'count': 1},
#   {'term': 'HEMIPLEGIA', 'count': 1},
#   {'term': 'HEMISENSORY NEGLECT', 'count': 1},
#   {'term': 'HENOCH-SCHONLEIN PURPURA', 'count': 1},
#   {'term': 'HEPATIC CANCER METASTATIC', 'count': 1},
#   {'term': 'HEPATIC EMBOLISATION', 'count': 1},
#   {'term': 'HEPATIC ENZYME ABNORMAL', 'count': 1},
#   {'term': 'HEPATIC ISCHAEMIA', 'count': 1},
#   {'term': 'HEPATIC LESION', 'count': 1},
#   {'term': 'HEPATIC MASS', 'count': 1},
#   {'term': 'HEPATIC NEOPLASM', 'count': 1},
#   {'term': 'HEPATITIS C', 'count': 1},
#   {'term': 'HEPATITIS FULMINANT', 'count': 1},
#   {'term': 'HEPATOCELLULAR CARCINOMA', 'count': 1},
#   {'term': 'HEPATOMEGALY', 'count': 1},
#   {'term': 'HEPATORENAL FAILURE', 'count': 1},
#   {'term': 'HERNIA', 'count': 1},
#   {'term': 'HERNIA OBSTRUCTIVE', 'count': 1},
#   {'term': 'HERNIAL EVENTRATION', 'count': 1},
#   {'term': 'HERPES VIRUS INFECTION', 'count': 1},
#   {'term': 'HIATUS HERNIA', 'count': 1},
#   {'term': 'HIGH DENSITY LIPOPROTEIN INCREASED', 'count': 1},
#   {'term': 'HUMERUS FRACTURE', 'count': 1},
#   {'term': 'HYALOSIS ASTEROID', 'count': 1},
#   {'term': 'HYDROTHORAX', 'count': 1}]}

# %%
agg_df = pd.DataFrame(j['results'])
agg_df.head()
# Out:
#                   term  count
# 0                DEATH    420
# 1  DISEASE PROGRESSION    256
# 2            DIARRHOEA    106
# 3               NAUSEA     98
# 4             VOMITING     92

# %%
continue_flag = 1
limit=1000
skip_count=0
while continue_flag==1:
    query_url = f'https://api.fda.gov/drug/event.json?search=patient.drug.openfda.brand_name:%22avastin%22+AND+serious:1+AND+patient.patientsex:1+AND+receivedate:[2013-01-01+TO+2013-12-31]&count=patient.reaction.reactionmeddrapt.exact&limit={limit}&skip={skip_count}'
    print(query_url)
    skip_count = skip_count + limit
    r = requests.get(query_url)
    j = json.loads(r.content)
    print(len(j['results']))
    if len(j['results'])!=1000:
        continue_flag==0
# Out:
# https://api.fda.gov/drug/event.json?search=patient.drug.openfda.brand_name:%22avastin%22+AND+serious:1+AND+patient.patientsex:1+AND+receivedate:[2013-01-01+TO+2013-12-31]&count=patient.reaction.reactionmeddrapt.exact&limit=1000&skip=0
# 1000
# https://api.fda.gov/drug/event.json?search=patient.drug.openfda.brand_name:%22avastin%22+AND+serious:1+AND+patient.patientsex:1+AND+receivedate:[2013-01-01+TO+2013-12-31]&count=patient.reaction.reactionmeddrapt.exact&limit=1000&skip=1000
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-9a4beae1b428> in <module>
#       8     r = requests.get(query_url)
#       9     j = json.loads(r.content)
# ---> 10     print(len(j['results']))
#      11     if len(j['results'])!=1000:
#      12         continue_flag==0
#
# KeyError: 'results'

# %% [markdown]
# It seem, skip clause can't be used with count queries
# https://opendata.stackexchange.com/questions/2163/how-to-get-total-count-of-adverse-effects-events-by-manufacturer-in-openfda

# %%
def get_data(query_url):
    r = requests.get(query_url)
    j = json.loads(r.content)
    return(pd.DataFrame(j['results']))

# %%
male_serious_url = f'https://api.fda.gov/drug/event.json?search=patient.drug.openfda.brand_name:%22avastin%22+AND+serious:1+AND+patient.patientsex:1+AND+receivedate:[2013-01-01+TO+2013-12-31]&count=patient.reaction.reactionmeddrapt.exact&limit=1000'
female_serious_url = f'https://api.fda.gov/drug/event.json?search=patient.drug.openfda.brand_name:%22avastin%22+AND+serious:1+AND+patient.patientsex:0+AND+receivedate:[2013-01-01+TO+2013-12-31]&count=patient.reaction.reactionmeddrapt.exact&limit=1000'
male_nonserious_url = f'https://api.fda.gov/drug/event.json?search=patient.drug.openfda.brand_name:%22avastin%22+AND+serious:2+AND+patient.patientsex:1+AND+receivedate:[2013-01-01+TO+2013-12-31]&count=patient.reaction.reactionmeddrapt.exact&limit=1000'
female_nonserious_url = f'https://api.fda.gov/drug/event.json?search=patient.drug.openfda.brand_name:%22avastin%22+AND+serious:2+AND+patient.patientsex:0+AND+receivedate:[2013-01-01+TO+2013-12-31]&count=patient.reaction.reactionmeddrapt.exact&limit=1000'

# %%
df_male_ser = get_data(male_serious_url)
df_female_ser = get_data(female_serious_url)
df_male_nonser = get_data(male_nonserious_url)
df_female_nonser = get_data(female_nonserious_url)

# %%
df_male_ser.shape, df_female_ser.shape, df_male_nonser.shape, df_female_nonser.shape
# Out:
# ((1000, 2), (482, 2), (48, 2), (17, 2))

# %%
def get_ae_pt_data(drug_brand_name):
    male_serious_url = f'https://api.fda.gov/drug/event.json?search=patient.drug.openfda.brand_name:%22{drug_brand_name}%22+AND+serious:1+AND+patient.patientsex:1+AND+receivedate:[2013-01-01+TO+2013-12-31]&count=patient.reaction.reactionmeddrapt.exact&limit=1000'
    female_serious_url = f'https://api.fda.gov/drug/event.json?search=patient.drug.openfda.brand_name:%22{drug_brand_name}%22+AND+serious:1+AND+patient.patientsex:0+AND+receivedate:[2013-01-01+TO+2013-12-31]&count=patient.reaction.reactionmeddrapt.exact&limit=1000'
    male_nonserious_url = f'https://api.fda.gov/drug/event.json?search=patient.drug.openfda.brand_name:%22{drug_brand_name}%22+AND+serious:2+AND+patient.patientsex:1+AND+receivedate:[2013-01-01+TO+2013-12-31]&count=patient.reaction.reactionmeddrapt.exact&limit=1000'
    female_nonserious_url = f'https://api.fda.gov/drug/event.json?search=patient.drug.openfda.brand_name:%22{drug_brand_name}%22+AND+serious:2+AND+patient.patientsex:0+AND+receivedate:[2013-01-01+TO+2013-12-31]&count=patient.reaction.reactionmeddrapt.exact&limit=1000'
    df_male_ser = get_data(male_serious_url)
    df_male_ser['gender']='male'
    df_male_ser['serious']=1
    df_female_ser = get_data(female_serious_url)
    df_female_ser['gender']='female'
    df_female_ser['serious']=1
    df_male_nonser = get_data(male_nonserious_url)
    df_male_nonser['gender']='male'
    df_male_nonser['serious']=0
    df_female_nonser = get_data(female_nonserious_url)
    df_female_nonser['gender']='female'
    df_female_nonser['serious']=0
    return(pd.concat([df_male_ser, df_female_ser,df_male_nonser,df_female_nonser], ignore_index=True))

# %%
tt = get_ae_pt_data('avastin')
tt.head()
# Out:
#                   term  count gender  serious
# 0                DEATH    420   male        1
# 1  DISEASE PROGRESSION    256   male        1
# 2            DIARRHOEA    106   male        1
# 3               NAUSEA     98   male        1
# 4             VOMITING     92   male        1

# %%
tt.tail()
# Out:
#                     term  count  gender  serious
# 1542                RASH      1  female        0
# 1543  SPINE MALFORMATION      1  female        0
# 1544    THROMBOCYTOPENIA      1  female        0
# 1545      VISION BLURRED      1  female        0
# 1546   VISUAL IMPAIRMENT      1  female        0
